# %%
import os
import pandas as pd

import matplotlib.pyplot as plt

os.chdir("D:\Collection\Programming Languages\ML Python\CSV")

data = pd.read_csv("test1.csv")


X = data['X']

Y = data['Y']
Z = data['Z']

plt.plot(X, Y , label ='Y', linestyle='-.')
plt.plot(X, Z , label ='Z', linestyle='-')

plt.legend()

plt.xlabel("marks")
plt.ylabel("Person")
# Out:
# Text(0, 0.5, 'Person')
